# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("datasets/diamonds.csv")
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.rename(columns={'Unnamed: 0': 'Number'}, inplace =True)

# %%
df.set_index('Number', inplace=True)

# %%
sns.lmplot(x='carat', y='price', data=df)

# %%
corr = stats_df.corr()

sns.heatmap(corr, vmin=-1, annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-449f0657287e> in <module>()
# ----> 1 corr = stats_df.corr()
#       2
#       3 sns.heatmap(corr, vmin=-1, annot=True)
#
# NameError: name 'stats_df' is not defined

# %%
df.rename(columns={'x': 'length'}, inplace =True)
df.rename(columns={'y': 'width'}, inplace =True)
df.rename(columns={'z': 'depth'}, inplace =True)

# %%
df.head()
# Out:
#         carat      cut color clarity  depth  table  price  length  width  \
# Number
# 1        0.23    Ideal     E     SI2   61.5   55.0    326    3.95   3.98
# 2        0.21  Premium     E     SI1   59.8   61.0    326    3.89   3.84
# 3        0.23     Good     E     VS1   56.9   65.0    327    4.05   4.07
# 4        0.29  Premium     I     VS2   62.4   58.0    334    4.20   4.23
# 5        0.31     Good     J     SI2   63.3   58.0    335    4.34   4.35
#
#         depth
# Number
# 1        2.43
# 2        2.31
# 3        2.31
# 4        2.63
# 5        2.75

# %%
sns.lmplot(x='length', y='width', data=df)

# %%
sns.boxplot(data=df)

# %%
sns.lmplot(x='table', y='depth', data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-635322b0a4b4> in <module>()
# ----> 1 sns.lmplot(x='table', y='depth', data=df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     577     if sharex:
#     578         for ax in facets.axes.flat:
# --> 579             ax.scatter(data[x], np.ones(len(data)) * data[y].mean()).remove()
#     580
#     581     # Draw the regression plot on each facet
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(left, right, name, na_op)
# ...

# %%
sns.lmplot(x='length', y='width', data=df)

# %%
sns.lmplot(x='clarity', y='width', data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-86c7ba1313ad> in <module>()
# ----> 1 sns.lmplot(x='clarity', y='width', data=df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     588         scatter_kws=scatter_kws, line_kws=line_kws,
#     589         )
# --> 590     facets.map_dataframe(regplot, x, y, **regplot_kws)
#     591
#     592     # Add a legend
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     795
#     796             # Draw the plot
# ...

# %%
df.set_index('clarity', inplace=True)

# %%
df.head()
# Out:
#          carat      cut color  depth  table  price  length  width  depth
# clarity
# SI2       0.23    Ideal     E   61.5   55.0    326    3.95   3.98   2.43
# SI1       0.21  Premium     E   59.8   61.0    326    3.89   3.84   2.31
# VS1       0.23     Good     E   56.9   65.0    327    4.05   4.07   2.31
# VS2       0.29  Premium     I   62.4   58.0    334    4.20   4.23   2.63
# SI2       0.31     Good     J   63.3   58.0    335    4.34   4.35   2.75

# %%
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-033902782ad7> in <module>()
# ----> 1 sns.pairplot(df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    2036     if grid.square_grid:
#    2037         if diag_kind == "hist":
# -> 2038             grid.map_diag(plt.hist, **diag_kws)
#    2039         elif diag_kind == "kde":
#    2040             diag_kws["legend"] = False
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_diag(self, func, **kwargs)
#    1352                 else:
#    1353                     func(vals, color=color, histtype="barstacked",
# -> 1354                          **kwargs)
#    1355             else:
# ...

# %%
sns.lmplot(x='price', y='table', data=df)

# %%
sns.lmplot(x='table', y='price', data=df)

# %%
sns.lmplot(x='table', y='cut', data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#     767         try:
# --> 768             x = float(x)
#     769         except Exception:
#
# ...

# %%
df.set_index('cut', inplace=True)

# %%
sns.lmplot(x='price', y='carat', data=df)

# %%
sns.boxplot(data=df)

# %%
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-033902782ad7> in <module>()
# ----> 1 sns.pairplot(df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    2036     if grid.square_grid:
#    2037         if diag_kind == "hist":
# -> 2038             grid.map_diag(plt.hist, **diag_kws)
#    2039         elif diag_kind == "kde":
#    2040             diag_kws["legend"] = False
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_diag(self, func, **kwargs)
#    1352                 else:
#    1353                     func(vals, color=color, histtype="barstacked",
# -> 1354                          **kwargs)
#    1355             else:
# ...

# %%
FL=11
IF=10
VVS1=9
VVS2=8
VS1=7
VS2=6
SI1=5
SI2=4
I1=3
I2=2
I3=1

# %%
I3
# Out:
# 1

# %%
df.head()
# Out:
#          carat color  depth  table  price  length  width  depth
# cut
# Ideal     0.23     E   61.5   55.0    326    3.95   3.98   2.43
# Premium   0.21     E   59.8   61.0    326    3.89   3.84   2.31
# Good      0.23     E   56.9   65.0    327    4.05   4.07   2.31
# Premium   0.29     I   62.4   58.0    334    4.20   4.23   2.63
# Good      0.31     J   63.3   58.0    335    4.34   4.35   2.75

# %%
df.head()
# Out:
#          carat color  depth  table  price  length  width  depth
# cut
# Ideal     0.23     E   61.5   55.0    326    3.95   3.98   2.43
# Premium   0.21     E   59.8   61.0    326    3.89   3.84   2.31
# Good      0.23     E   56.9   65.0    327    4.05   4.07   2.31
# Premium   0.29     I   62.4   58.0    334    4.20   4.23   2.63
# Good      0.31     J   63.3   58.0    335    4.34   4.35   2.75

# %%
df.head()
# Out:
#          carat color  depth  table  price  length  width  depth
# cut
# Ideal     0.23     E   61.5   55.0    326    3.95   3.98   2.43
# Premium   0.21     E   59.8   61.0    326    3.89   3.84   2.31
# Good      0.23     E   56.9   65.0    327    4.05   4.07   2.31
# Premium   0.29     I   62.4   58.0    334    4.20   4.23   2.63
# Good      0.31     J   63.3   58.0    335    4.34   4.35   2.75

# %%
sns.boxplot(data=df)

# %%
df.head()
# Out:
#          carat color  depth  table  price  length  width  depth
# cut
# Ideal     0.23     E   61.5   55.0    326    3.95   3.98   2.43
# Premium   0.21     E   59.8   61.0    326    3.89   3.84   2.31
# Good      0.23     E   56.9   65.0    327    4.05   4.07   2.31
# Premium   0.29     I   62.4   58.0    334    4.20   4.23   2.63
# Good      0.31     J   63.3   58.0    335    4.34   4.35   2.75

# %%
df.set_index('Number', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-2e9fcd4eb6ad> in <module>()
# ...

# %%
df.set_index('Number', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-2e9fcd4eb6ad> in <module>()
# ...

# %%
df.head()
# Out:
#          carat color  depth  table  price  length  width  depth
# cut
# Ideal     0.23     E   61.5   55.0    326    3.95   3.98   2.43
# Premium   0.21     E   59.8   61.0    326    3.89   3.84   2.31
# Good      0.23     E   56.9   65.0    327    4.05   4.07   2.31
# Premium   0.29     I   62.4   58.0    334    4.20   4.23   2.63
# Good      0.31     J   63.3   58.0    335    4.34   4.35   2.75

# %%
df.set_index('clarity', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'clarity'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-a808115ab097> in <module>()
# ...

# %%
sns.violinplot(x='price',
               y='carat',
               data=df,
               inner=None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-5a319b41da65> in <module>()
#       2                y='carat',
#       3                data=df,
# ----> 4                inner=None)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2343                              bw, cut, scale, scale_hue, gridsize,
#    2344                              width, inner, split, dodge, orient, linewidth,
# -> 2345                              color, palette, saturation)
#    2346
#    2347     if ax is None:
#
# ...

# %%
df.head()
# Out:
#         carat      cut color clarity  depth  table  price  length  width  \
# Number
# 1        0.23    Ideal     E     SI2   61.5   55.0    326    3.95   3.98
# 2        0.21  Premium     E     SI1   59.8   61.0    326    3.89   3.84
# 3        0.23     Good     E     VS1   56.9   65.0    327    4.05   4.07
# 4        0.29  Premium     I     VS2   62.4   58.0    334    4.20   4.23
# 5        0.31     Good     J     SI2   63.3   58.0    335    4.34   4.35
#
#         depth
# Number
# 1        2.43
# 2        2.31
# 3        2.31
# 4        2.63
# 5        2.75

# %%
plt.show()

# %%
df.head()
# Out:
#         carat      cut color clarity  depth  table  price  length  width  \
# Number
# 1        0.23    Ideal     E     SI2   61.5   55.0    326    3.95   3.98
# 2        0.21  Premium     E     SI1   59.8   61.0    326    3.89   3.84
# 3        0.23     Good     E     VS1   56.9   65.0    327    4.05   4.07
# 4        0.29  Premium     I     VS2   62.4   58.0    334    4.20   4.23
# 5        0.31     Good     J     SI2   63.3   58.0    335    4.34   4.35
#
#         depth
# Number
# 1        2.43
# 2        2.31
# 3        2.31
# 4        2.63
# 5        2.75

# %%
sns.lmplot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-ab0bf748786d> in <module>()
# ----> 1 sns.lmplot()
#
# TypeError: lmplot() missing 3 required positional arguments: 'x', 'y', and 'data'

# %%
sns.lmplot(x='carat', y='price', data=df, 
           fit_reg=False, #remove regression line
           hue='clarity')   #color by evolution stage

# %%
sns.lmplot(x='carat', y='price', data=df, 
           fit_reg=False, #remove regression line
           hue='cut')   #color by evolution stage

# %%
sns.violinplot(data=df)

# %%
corr = df.corr()

sns.heatmap(corr, vmin=-1, annot=True)

# %%
sns.distplot(df['price'])

# %%
df.corr()
# Out:
#            carat     depth     table     price    length     width     depth
# carat   1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth   0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table   0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price   0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# length  0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# width   0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# depth   0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
sns.distplot(df['carat'])

# %%
import statsmodels.formula.api as smf

# %%
result = smf.ols('price ~ age + exercise + hours', data=df).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\patsy\compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#     116     try:
# --> 117         return f(*args, **kwargs)
#     118     except Exception as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\patsy\eval.py in eval(self, expr, source_name, inner_namespace)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#
# <string> in <module>()
#
# NameError: name 'lenght' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-158-b1190fe0ab31> in <module>()
# ...
